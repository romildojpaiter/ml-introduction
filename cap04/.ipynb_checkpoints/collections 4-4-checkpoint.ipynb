# %%
import pandas as pd

df = pd.read_csv("buscas_sim_nao.csv")
X_df = df[['home', 'busca', 'logado']]
Y_df = df['comprou']

Xdummies_df = pd.get_dummies(X_df)
Ydummies_df = Y_df

X = Xdummies_df.values
Y = Ydummies_df.values

# %%
list(Y)
# Out:
# ['yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
# ...

# %%
list(Y).count('yes')
# Out:
# 832

# %%
list(Y).count('no')
# Out:
# 168

# %%
# restante do código
acerto_de_um = list(Y).count('yes')
acerto_de_zero = list(Y).count('no')
# Out:
#   Cell In[6], line 3
#     acerto_de_zero = list(Y).count('nao'
#                                         ^
# SyntaxError: incomplete input
